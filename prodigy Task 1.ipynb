# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv(r'C:\Users\Sudarsan\OneDrive\sudarsun\prodgy infotech intern\task 1 data.csv')

# %%
data
# Out:
#            Data Source World Development Indicators         Unnamed: 2  \
# 0                  NaN                          NaN                NaN
# 1    Last Updated Date                   28-03-2024                NaN
# 2                  NaN                          NaN                NaN
# 3         Country Name                 Country Code     Indicator Name
# 4                Aruba                          ABW  Population, total
# ..                 ...                          ...                ...
# 265             Kosovo                          XKX  Population, total
# 266        Yemen, Rep.                          YEM  Population, total
# 267       South Africa                          ZAF  Population, total
# 268             Zambia                          ZMB  Population, total
# 269           Zimbabwe                          ZWE  Population, total
#
#          Unnamed: 3        Ages   Frequency  Unnamed: 6  Unnamed: 7  \
# ...

# %%
# Create the histogram
plt.figure(figsize=(8, 6))
plt.hist(data['Ages'], bins=10, color='navy', edgecolor='white')
plt.title('Distribution of Ages')
plt.xlabel('Ages')
plt.ylabel('Frequency')
plt.show()
